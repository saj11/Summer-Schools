# %%
# !tar chvzf notebook.tar.gz --exclude notebook.tar.gz *
# Out:
# Introduction_to_Data_Science/
# Introduction_to_Data_Science/.ipynb_checkpoints/
# Introduction_to_Data_Science/.ipynb_checkpoints/EVeMa - Intro to Data Science-checkpoint.ipynb
# Introduction_to_Data_Science/EVeMa - Intro to Data Science.ipynb
# Introduction_to_Data_Science/names.csv
# Introduction_to_Data_Science/postgresql-42.1.4.jar
# Introduction_to_Data_Science/exchange_rates.csv
# Introduction_to_Data_Science/assets/
# Introduction_to_Data_Science/assets/logo.jpg
# keras_xor/
# keras_xor/Keras XOR example.ipynb
# keras_xor/.ipynb_checkpoints/
# keras_xor/.ipynb_checkpoints/Keras XOR example-checkpoint.ipynb
# keras_xor/xor_model.png
# keras_xor/saved_weights.h5
# keras_xor/patient-w-lublana.jpeg
# keras_xor/evema-logo.jpeg
# mpd.hosts
# Session1/
# Session1/MatrixCalculus/
# Session1/MatrixCalculus/LeastSquares.ipynb
# Session1/MatrixCalculus/.ipynb_checkpoints/
# Session1/MatrixCalculus/.ipynb_checkpoints/LeastSquares-checkpoint.ipynb
# ...
